# %% [markdown]
# <a href="https://colab.research.google.com/github/robert-maddoxjr-gmail-com/DAPP-Skillspire/blob/main/DAPP_train_1b_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df_train = pd.read_csv("https://raw.githubusercontent.com/DrakeData/DAPP-Skillspire/main/train.csv")

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(111, projection= '3d')

ax.scatter(df_train['LotFrontage'], df_train['SalePrice'], df_train['LotArea'], c='blue', marker='o')

ax.set_xlabel('LotFrontage')
ax.set_ylabel('SalePrice')
ax.set_zlabel('Lot Area')

plt.title('3D Scatter Plot')
plt.show()

# %%
# !pip install pandas-profiling

# %%
# Check the number of non-null values in the 'YrSold' column
yr_sold_count = df_train['YrSold'].count()

#Check the number of non-null values in the 'SalePrice' column
sale_price_count = df_train['SalePrice'].count()

print(f"Non-null values in SalePrice: {sale_price_count}")
print(f"Non-null values in Age: {yr_sold_count}")
# Out:
# Non-null values in SalePrice: 1460
# Non-null values in Age: 1460

# %%
print(df_train['SalePrice'].dtype)
print(df_train['YrSold'].dtype)
# Out:
# int64
# int64

# %%
df_train['SalePrice'] = df_train['SalePrice'].astype(float)
df_train['YrSold'] = pd.to_datetime(df_train['YrSold'], format='%Y')

# %%
print(df_train['SalePrice'].dtype)
print(df_train['YrSold'].dtype)
# Out:
# float64
# datetime64[ns]

# %%
# Convert 'current_year' to datetime
current_year = pd.to_datetime(current_year, format='%Y')

# Calculate the age of each house
df_train['Age'] = current_year.year - df_train['YrSold'].dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Assuming you have a DataFrame called 'df' with columns 'YrSold' and 'SalePrice'

# Calculate the age of each house

df_train['Age'] = 2023 - df_train['YrSold'].dt.year


# Prepare the data for regression
X = df_train[['Age']]  # Independent variable (age)
y = df_train['SalePrice']  #Dependent variable (SalePrice)

# Initialize the llinear regression model

model = LinearRegression()

# Fit the model
model.fit(X,y)

# Get the coefficients
slope = model.coef_[0]
intercept = model.intercept_

# Print the regression equation
print(f"SalePrice = {slope:2f} * Age + [intercept:.2f]")

# Visualize the relationship
plt.scatter(df_train['Age'], df_train['SalePrice'], color='red')
plt.plot(df_train['Age'], model.predict(X), color = 'blue', linewidth=2)
plt.xlabel('Age')
plt.ylabel('SalePrice')
plt.title('Regression Analysis: Age vs. Sale Price')
plt.show
# Out:
# SalePrice = 1730.058729 * Age + [intercept:.2f]
# <function matplotlib.pyplot.show(close=None, block=None)>
